# %% [markdown]
# # 08 - Création du dataset de données traitées pour entrainement <br> avec filtre des évènements par id
# (sans encodage, ni normalisation)

# %% [markdown]
# Ce notebook génère 1 csv :
#
# - dataset_for_training.csv : analyse et nettoyage des variables explicatives
#
# Etapes :

# %% [markdown]
# ## A) Imports

# %%
import os
import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np
# from ydata_profiling import ProfileReport # pip install ydata_profiling ipywidgets
import matplotlib.pyplot as plt

# %%
# source path to datasets
path = '../data/'
data = 'dataset_for_preprocess_id_events_filtered_07.csv'
save_csv = '../data/dataset_for_training_id_events_filtered_08.csv'

# %%
# création d'un dataframe à partir du csv de données
df = pd.read_csv(os.path.join(path, data), header=0, parse_dates=True, index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3101 entries, 0 to 3100
# Data columns (total 49 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   started_at                                            3101 non-null   object
#  1   ended_at                                              3101 non-null   object
#  2   paperHeight_job                                       3101 non-null   int64
#  3   paperWidth_job                                        3101 non-null   int64
#  4   scanner_mode                                          3101 non-null   int64
#  5   bars_job                                              3101 non-null   int64
#  6   varnishConsumptionVarnish_3d_job                      3101 non-null   float64
#  7   run                                                   3101 non-null   int64
#  8   total_run                                             3101 non-null   int64
#  9   copies_per_run                                        3101 non-null   int64
#  10  jobId                                                 3101 non-null   int64
#  11  total_copies_requested                                3101 non-null   int64
#  12  LED                                                   3101 non-null   int64
#  13  bars_event                                            3101 non-null   object
#  14  drops                                                 3101 non-null   int64
#  15  dithering                                             3101 non-null   bool
#  16  deadPixelsOffset                                      3101 non-null   int64
#  17  operator_level                                        3101 non-null   object
#  18  operator                                              3101 non-null   object
#  19  speed_ifoil                                           3101 non-null   float64
#  20  ifoil                                                 3101 non-null   bool
#  21  optifoil_ifoil                                        3101 non-null   bool
#  22  stampAreas_ifoil                                      3101 non-null   object
#  23  heater1Enabled_ifoil                                  3101 non-null   bool
#  24  speedTensionIn_ifoil                                  3101 non-null   float64
#  25  heater1Temperature_ifoil                              3101 non-null   int64
#  26  x_imageLayout                                         3101 non-null   int64
#  27  y_imageLayout                                         3101 non-null   int64
#  28  paperName                                             3101 non-null   object
#  29  paperWidth_event                                      3101 non-null   float64
#  30  paperHeight_event                                     3101 non-null   float64
#  31  speed                                                 3101 non-null   int64
#  32  power_irDryers                                        3101 non-null   int64
#  33  power_uvDryers                                        3101 non-null   int64
#  34  topMargin_remoteScannerRegistration                   3101 non-null   int64
#  35  leftMargin_remoteScannerRegistration                  3101 non-null   int64
#  36  redScore_gridMode_remoteScannerRegistration           3101 non-null   int64
#  37  redScore_cropmarksMode_remoteScannerRegistration      3101 non-null   int64
#  38  redScore_fullScannerMode_remoteScannerRegistration    3101 non-null   int64
#  39  blueScore_fullScannerMode_remoteScannerRegistration   3101 non-null   int64
#  40  greenScore_fullScannerMode_remoteScannerRegistration  3101 non-null   int64
#  41  mode_remoteScannerRegistration                        3101 non-null   int64
#  42  jobState                                              3101 non-null   object
#  43  total_copies                                          3101 non-null   int64
#  44  varnishConsumptionVarnish_3d_event                    3101 non-null   float64
#  45  index                                                 3101 non-null   int64
#  46  timestamp                                             3101 non-null   object
#  47  criticality_events                                    3101 non-null   object
#  48  identification_events                                 3101 non-null   int64
# dtypes: bool(4), float64(6), int64(29), object(10)
# memory usage: 1.1+ MB

# %%
df14 = ['started_at', 'ended_at', 'paperHeight_job', 'paperWidth_job',
       'scanner_mode', 'bars_job', 'varnishConsumptionVarnish_3d_job', 'run',
       'total_run', 'copies_per_run', 'jobId', 'total_copies_requested', 'LED',
       'bars_event', 'drops', 'dithering', 'deadPixelsOffset',
       'operator_level', 'operator', 'speed_ifoil', 'ifoil', 'optifoil_ifoil',
       'stampAreas_ifoil', 'heater1Enabled_ifoil', 'speedTensionIn_ifoil',
       'heater1Temperature_ifoil', 'x_imageLayout', 'y_imageLayout',
       'paperName', 'paperWidth_event', 'paperHeight_event', 'speed',
       'power_irDryers', 'power_uvDryers',
       'topMargin_remoteScannerRegistration',
       'leftMargin_remoteScannerRegistration',
       'redScore_gridMode_remoteScannerRegistration',
       'redScore_cropmarksMode_remoteScannerRegistration',
       'redScore_fullScannerMode_remoteScannerRegistration',
       'blueScore_fullScannerMode_remoteScannerRegistration',
       'greenScore_fullScannerMode_remoteScannerRegistration',
       'mode_remoteScannerRegistration', 'jobState', 'total_copies',
       'varnishConsumptionVarnish_3d_event', 'index', 'timestamp',
       'criticality_events', 'identification_events']

df17 =['total_copies_job', 'started_at', 'ended_at', 'paperHeight_job',
       'paperWidth_job', 'scanner_mode', 'bars_job',
       'varnishConsumptionVarnish_3d_job', 'run', 'total_run',
       'copies_per_run', 'jobId', 'total_copies_requested', 'LED',
       'bars_event', 'drops', 'dithering', 'deadPixelsOffset',
       'operator_level', 'operator', 'speed_ifoil', 'ifoil', 'optifoil_ifoil',
       'stampAreas_ifoil', 'heater1Enabled_ifoil', 'speedTensionIn_ifoil',
       'speedTensionOut_ifoil', 'heater1Temperature_ifoil', 'x_imageLayout',
       'y_imageLayout', 'paperName', 'paperWidth_event', 'paperHeight_event',
       'speed', 'power_irDryers', 'power_uvDryers',
       'redScore_gridMode_remoteScannerRegistration',
       'redScore_cropmarksMode_remoteScannerRegistration',
       'x_cropmark1_cropmarksMode_remoteScannerRegistration',
       'y_cropmark1_cropmarksMode_remoteScannerRegistration',
       'x_cropmark2_cropmarksMode_remoteScannerRegistration',
       'y_cropmark2_cropmarksMode_remoteScannerRegistration',
       'exposureTime_manualLighting_remoteScannerRegistration',
       'redScore_fullScannerMode_remoteScannerRegistration',
       'blueScore_fullScannerMode_remoteScannerRegistration',
       'greenScore_fullScannerMode_remoteScannerRegistration',
       'enable_specialSubstrate_remoteScannerRegistration',
       'mode_remoteScannerRegistration', 'jobState', 'total_copies_event',
       'varnishConsumptionVarnish_3d_event', 'index', 'timestamp',
       'criticality_events', 'identification_events']

# df14 et df17 sont vos listes de colonnes

# Convertir les listes en ensembles
colonnes_df17 = set(df17)
colonnes_df14 = set(df14)

# Trouver les colonnes uniques à df17
colonnes_uniques_df17 = colonnes_df17 - colonnes_df14
print("Colonnes uniques à df17 (machine 17) :")
print(colonnes_uniques_df17)

# Trouver les colonnes uniques à df14
colonnes_uniques_df14 = colonnes_df14 - colonnes_df17
print("\nColonnes uniques à df14 (machine 14) :")
print(colonnes_uniques_df14)
# Out:
# Colonnes uniques à df17 (machine 17) :
# {'x_cropmark2_cropmarksMode_remoteScannerRegistration', 'total_copies_event', 'total_copies_job', 'speedTensionOut_ifoil', 'y_cropmark1_cropmarksMode_remoteScannerRegistration', 'enable_specialSubstrate_remoteScannerRegistration', 'x_cropmark1_cropmarksMode_remoteScannerRegistration', 'y_cropmark2_cropmarksMode_remoteScannerRegistration', 'exposureTime_manualLighting_remoteScannerRegistration'}
#
# Colonnes uniques à df14 (machine 14) :
# {'topMargin_remoteScannerRegistration', 'total_copies', 'leftMargin_remoteScannerRegistration'}

# %%
# Liste des colonnes à vérifier
colonnes_a_verifier = ['topMargin_remoteScannerRegistration', 'leftMargin_remoteScannerRegistration']


# Afficher la répartition des valeurs pour chaque colonne dans la liste
for col in colonnes_a_verifier:
    print(f"Valeurs uniques pour {col}: {df[col].unique()}")
    print(f"Répartition des valeurs pour {col}:")
    print(df[col].value_counts())
    print("\n")
# Out:
# Valeurs uniques pour topMargin_remoteScannerRegistration: [  0 -71]
# Répartition des valeurs pour topMargin_remoteScannerRegistration:
#  0     3100
# -71       1
# Name: topMargin_remoteScannerRegistration, dtype: int64
#
#
# Valeurs uniques pour leftMargin_remoteScannerRegistration: [  0 -71  71]
# Répartition des valeurs pour leftMargin_remoteScannerRegistration:
#  0     2810
# -71     277
#  71      14
# Name: leftMargin_remoteScannerRegistration, dtype: int64

# %% [markdown]
# ## B) Analyse des variables

# %%
# remise à zero des index
df.reset_index(drop=True,inplace=True)

# %%
# suppression des colonnes de metrics
# metrics_cols = [
#     'status', 
#     'source_events', 
#     'timestamp', 
#     'criticality_events', 
#     'name_modules', 
#     'type_modules',
#     'generation_modules', 
#     'value_counters_modules', 
#     'name_counters_modules',
#     'name_connected_operators',
#     'level_connected_operators',
#     'varnishLevelsTargetvolume',
#     'varnishLevelsTotalvolume'
#     ]
metrics_cols = [
    'timestamp', 
    'criticality_events', 
    'index',
    ]
df.drop(columns=metrics_cols, axis=0, inplace=True)

# %%
# suppression des colonnes en doublon entre job_events et jobs
job_events_cols = [
    'bars_event',
    'paperWidth_event', 
    'paperHeight_event',
    'varnishConsumptionVarnish_3d_event'
    ]
df.drop(columns=job_events_cols, axis=0, inplace=True)

# %%
# suppression des colonnes de variables catégorielles
cat_cols = [
    'operator_level', 
    'operator',
    'paperName', 
    'jobState',
    'jobId'
   ]
df.drop(columns=cat_cols, axis=0, inplace=True)

# %%
# suppression des colonnes datetime et ajout d'une colonne duration
df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])
# Calculer la différence de temps entre les deux colonnes
df['duration'] = (df['ended_at'] - df['started_at']).dt.total_seconds()
df.drop(columns=['started_at', 'ended_at'], axis=0, inplace=True)

# %%
df.head(3)
# Out:
#    paperHeight_job  paperWidth_job  scanner_mode  bars_job  \
# 0              520             740             1         2
# 1              520             740             1         2
# 2              520             740             1         2
#
#    varnishConsumptionVarnish_3d_job  run  total_run  copies_per_run  \
# 0                          0.000000    0          0               0
# 1                          0.000000    0          0               0
# 2                         14.013516    0          0               0
#
#    total_copies_requested  LED  drops  dithering  deadPixelsOffset  \
# 0                     125   30      4      False                 0
# 1                     300   10      1      False                 0
# 2                     200   10      1      False                 0
#
#    speed_ifoil  ifoil  optifoil_ifoil  \
# 0         22.0  False            True
# 1         42.0  False            True
# 2         42.0  False            True
#
#                                     stampAreas_ifoil  heater1Enabled_ifoil  \
# 0  [{'id': 1, 'end': 519, 'start': 0, 'height': 5...                 False
# 1  [{'id': 1, 'end': 519, 'start': 0, 'height': 5...                 False
# 2  [{'id': 1, 'end': 519, 'start': 0, 'height': 5...                 False
#
#    speedTensionIn_ifoil  heater1Temperature_ifoil  x_imageLayout  \
# 0                  -0.2                       115             70
# 1                  -0.2                       115             70
# 2                  -0.2                       115             70
#
#    y_imageLayout  speed  power_irDryers  power_uvDryers  \
# 0              0    181              45             100
# 1              0    312              45             100
# 2              0    290              45             100
#
#    topMargin_remoteScannerRegistration  leftMargin_remoteScannerRegistration  \
# 0                                    0                                     0
# 1                                    0                                     0
# 2                                    0                                     0
#
#    redScore_gridMode_remoteScannerRegistration  \
# 0                                         1500
# 1                                         3115
# 2                                         3048
#
#    redScore_cropmarksMode_remoteScannerRegistration  \
# 0                                              1500
# 1                                              3115
# 2                                              3048
#
#    redScore_fullScannerMode_remoteScannerRegistration  \
# 0                                               1500
# 1                                               3115
# 2                                               3048
#
#    blueScore_fullScannerMode_remoteScannerRegistration  \
# 0                                                 16
# 1                                                 33
# 2                                                 33
#
#    greenScore_fullScannerMode_remoteScannerRegistration  \
# 0                                                 16
# 1                                                 33
# 2                                                 33
#
#    mode_remoteScannerRegistration  total_copies  identification_events  \
# 0                               1             0                    325
# 1                               1             0                   1003
# 2                               1            22                    445
#
#    duration
# 0    19.809
# 1   548.817
# 2   333.072

# %% [markdown]
# ### a) Profiling report

# %%
# profile = ProfileReport(df, title="Profiling Report")
# profile.to_notebook_iframe()

# %% [markdown]
# ## C) Nettoyage

# %%
# Liste des colonnes pour lesquelles vous voulez voir les valeurs uniques
colonnes_a_verifier = ['dithering','deadPixelsOffset','speedTensionIn_ifoil']

# Afficher les valeurs uniques pour chaque colonne dans la liste
for col in colonnes_a_verifier:
    print(f"Valeurs uniques pour {col}: {df[col].unique()}")
# Out:
# Valeurs uniques pour dithering: [False]
# Valeurs uniques pour deadPixelsOffset: [0]
# Valeurs uniques pour speedTensionIn_ifoil: [-0.2]

# %%
# supression des colonnes dont les valeurs sont constantes
contstant_cols = ['dithering','deadPixelsOffset','speedTensionIn_ifoil', 'topMargin_remoteScannerRegistration']
df.drop(columns=contstant_cols, axis=0, inplace=True)

# %%
df.head(5)
# Out:
#    paperHeight_job  paperWidth_job  scanner_mode  bars_job  \
# 0              520             740             1         2
# 1              520             740             1         2
# 2              520             740             1         2
# 3              520             740             1         2
# 4              450             320             1         1
#
#    varnishConsumptionVarnish_3d_job  run  total_run  copies_per_run  \
# 0                          0.000000    0          0               0
# 1                          0.000000    0          0               0
# 2                         14.013516    0          0               0
# 3                         88.591740    0          0               0
# 4                          0.038611    0          0               0
#
#    total_copies_requested  LED  drops  speed_ifoil  ifoil  optifoil_ifoil  \
# 0                     125   30      4    22.000000  False            True
# 1                     300   10      1    42.000000  False            True
# 2                     200   10      1    42.000000  False            True
# 3                     125   30      4    26.200001  False            True
# 4                      70   10      1    42.000000  False            True
#
#                                     stampAreas_ifoil  heater1Enabled_ifoil  \
# 0  [{'id': 1, 'end': 519, 'start': 0, 'height': 5...                 False
# 1  [{'id': 1, 'end': 519, 'start': 0, 'height': 5...                 False
# 2  [{'id': 1, 'end': 519, 'start': 0, 'height': 5...                 False
# 3  [{'id': 1, 'end': 519, 'start': 0, 'height': 5...                 False
# 4  [{'id': 1, 'end': 450, 'start': 0, 'height': 4...                 False
#
#    heater1Temperature_ifoil  x_imageLayout  y_imageLayout  speed  \
# 0                       115             70              0    181
# 1                       115             70              0    312
# 2                       115             70              0    290
# 3                       115             70              0    313
# 4                       115           3047              0    700
#
#    power_irDryers  power_uvDryers  leftMargin_remoteScannerRegistration  \
# 0              45             100                                     0
# 1              45             100                                     0
# 2              45             100                                     0
# 3              45             100                                     0
# 4              45             100                                     0
#
#    redScore_gridMode_remoteScannerRegistration  \
# 0                                         1500
# 1                                         3115
# 2                                         3048
# 3                                         3148
# 4                                         1500
#
#    redScore_cropmarksMode_remoteScannerRegistration  \
# 0                                              1500
# 1                                              3115
# 2                                              3048
# 3                                              3148
# 4                                              1500
#
#    redScore_fullScannerMode_remoteScannerRegistration  \
# 0                                               1500
# 1                                               3115
# 2                                               3048
# 3                                               3148
# 4                                               1500
#
#    blueScore_fullScannerMode_remoteScannerRegistration  \
# 0                                                 16
# 1                                                 33
# 2                                                 33
# 3                                                 32
# 4                                                 16
#
#    greenScore_fullScannerMode_remoteScannerRegistration  \
# 0                                                 16
# 1                                                 33
# 2                                                 33
# 3                                                 32
# 4                                                 16
#
#    mode_remoteScannerRegistration  total_copies  identification_events  \
# 0                               1             0                    325
# 1                               1             0                   1003
# 2                               1            22                    445
# 3                               1            88                    453
# 4                               1             2                    354
#
#    duration
# 0    19.809
# 1   548.817
# 2   333.072
# 3   448.970
# 4    39.731

# %% [markdown]
# Données disponibles au démarrage d'un job :
# - 1  thumbnail* : chemin vignette projet
# - 2  total_copies : nombre de copies imprimées
# - 3  started_at : date de début
# - 4  ended_at : date de fin
# - 5  machineId* : identifiant machine
# - 6  speed : vitesse d'impression
# - 7  operator : opérateur
# - 8  operator_level : niveau de l'opérateur
# - 9  first_page_image_path_on_machine* : chemin de l'image
# - 10 paperHeight : hauteur du substrat
# - 11 paperWidth : largeur du substrat
# - 12 paperName : appelation du substrat
# - 13 paperThickness* : épaisseur du substrat (valeur unique à 0)
# - 14 id_on_machine : identifiant unique du travail d'impression
# - 15 total_copies_requested : nombre de copies demandées
# - 16 job_thumbnail_id* : identifiant de vignette image
# - 17 uses_ifoil : impression utilisant de la dorure
# - 18 uses_iper* : impression nécéssitant l'iper (valeur unique à True)
# - 19 scanner_mode : niveau de config du scanner
# - 20 iper_bvar_count : compteur # TODO vérifier la fusion notebook 06
# - 21 varnishConsumptionVarnish_3d : consommation de vernis en 3d
# - 22 varnishConsumptionVarnish_2d* : consommation de vernis en 2d
#
# *\*variables déjà supprimées dans le notebook 05 ou 06*

# %%
# colonnes à conserver dispos dans jobs
jobs_cols_to_keep = [
    'duration',
    'total_copies',
    'speed',
    'paperHeight_job', 
    'paperWidth_job', 
    'total_copies_requested',
    'ifoil',
    'scanner_mode', 
    'bars_job', # TODO vérifier les valeurs de la variable d'origine iper_bvar_count
    'varnishConsumptionVarnish_3d_job'
    ]
# colonnes à conserver dispos dans job events avec le tag start
jobevents_cols_to_keep = [
    'LED',
    'drops', 
    'speed_ifoil',
    'optifoil_ifoil', 
    'stampAreas_ifoil',
    'heater1Enabled_ifoil', 
    'heater1Temperature_ifoil',
    'x_imageLayout',
    'y_imageLayout', 
    'power_irDryers', 
    'power_uvDryers',
    'leftMargin_remoteScannerRegistration',
    'redScore_gridMode_remoteScannerRegistration',
    'redScore_cropmarksMode_remoteScannerRegistration',
    'redScore_fullScannerMode_remoteScannerRegistration',
    'blueScore_fullScannerMode_remoteScannerRegistration',
    'greenScore_fullScannerMode_remoteScannerRegistration',
    'mode_remoteScannerRegistration'
    ]
# colonnes à conserver pour la prédiction
metrics_cols_to_keep = ['identification_events']

# fusion des listes de colonnes à conserver
cols_to_keep = jobs_cols_to_keep + jobevents_cols_to_keep + metrics_cols_to_keep

# dataframe des variables conservées
df_to_encode = df[cols_to_keep].copy()

# %%
df_to_encode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3101 entries, 0 to 3100
# Data columns (total 29 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   duration                                              3101 non-null   float64
#  1   total_copies                                          3101 non-null   int64
#  2   speed                                                 3101 non-null   int64
#  3   paperHeight_job                                       3101 non-null   int64
#  4   paperWidth_job                                        3101 non-null   int64
#  5   total_copies_requested                                3101 non-null   int64
#  6   ifoil                                                 3101 non-null   bool
#  7   scanner_mode                                          3101 non-null   int64
#  8   bars_job                                              3101 non-null   int64
#  9   varnishConsumptionVarnish_3d_job                      3101 non-null   float64
#  10  LED                                                   3101 non-null   int64
#  11  drops                                                 3101 non-null   int64
#  12  speed_ifoil                                           3101 non-null   float64
#  13  optifoil_ifoil                                        3101 non-null   bool
#  14  stampAreas_ifoil                                      3101 non-null   object
#  15  heater1Enabled_ifoil                                  3101 non-null   bool
#  16  heater1Temperature_ifoil                              3101 non-null   int64
#  17  x_imageLayout                                         3101 non-null   int64
#  18  y_imageLayout                                         3101 non-null   int64
#  19  power_irDryers                                        3101 non-null   int64
#  20  power_uvDryers                                        3101 non-null   int64
#  21  leftMargin_remoteScannerRegistration                  3101 non-null   int64
#  22  redScore_gridMode_remoteScannerRegistration           3101 non-null   int64
#  23  redScore_cropmarksMode_remoteScannerRegistration      3101 non-null   int64
#  24  redScore_fullScannerMode_remoteScannerRegistration    3101 non-null   int64
#  25  blueScore_fullScannerMode_remoteScannerRegistration   3101 non-null   int64
#  26  greenScore_fullScannerMode_remoteScannerRegistration  3101 non-null   int64
#  27  mode_remoteScannerRegistration                        3101 non-null   int64
#  28  identification_events                                 3101 non-null   int64
# dtypes: bool(3), float64(3), int64(22), object(1)
# memory usage: 639.1+ KB

# %%
df_to_encode.drop(columns=['stampAreas_ifoil'], axis=0, inplace=True)

# %%
# cols = df_to_encode.columns
# for col in cols:
#     if df_to_encode[col].nunique() > 50 :
#         print(col, df_to_encode[col].nunique(), 'min', df_to_encode[col].min(), 'max', df_to_encode[col].max())
#     else :
#         print(col, df_to_encode[col].unique())

# %%
df_to_encode.identification_events.unique()
# Out:
# array([ 325, 1003,  445,  453,  354,  454,  387,  386, 1002,  357,  418,
#         355,  356,  480,  460, 1000,  416,  446,  411,  351,  471,  359,
#         470,  452,  442], dtype=int64)

# %% [markdown]
# ## D) Output

# %%
df_to_encode.to_csv(save_csv)
