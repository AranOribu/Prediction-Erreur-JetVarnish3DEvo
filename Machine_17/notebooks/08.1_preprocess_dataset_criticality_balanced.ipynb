# %% [markdown]
# <style>
#     .title {
#         font-weight: 'bold';
#     }
# </style>
#
# # <span class="title">08.1 - Création du dataset de données traitées pour entrainement </br> avec criticités équilibrées</span>
# (sans encodage, ni normalisation)

# %% [markdown]
# Ce notebook génère 1 csv :
#
# - dataset_for_training.csv : analyse et nettoyage des variables explicatives
#
# Etapes :

# %% [markdown]
# ## A) Imports

# %%
import os
import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np
import matplotlib.pyplot as plt

# %%
# source path to datasets
path = '../data/'
data = 'dataset_for_preprocess_criticality_balanced_07.1.csv'
save_csv = '../data/dataset_for_training_criticality_balanced_08.1.csv'

# %%
# création d'un dataframe à partir du csv de données
df = pd.read_csv(os.path.join(path, data), header=0, parse_dates=True, index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23533 entries, 0 to 25744
# Data columns (total 55 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   total_copies_job                                       23533 non-null  int64
#  1   started_at                                             23533 non-null  object
#  2   ended_at                                               23533 non-null  object
#  3   paperHeight_job                                        23533 non-null  int64
#  4   paperWidth_job                                         23533 non-null  int64
#  5   scanner_mode                                           23533 non-null  int64
#  6   bars_job                                               23533 non-null  int64
#  7   varnishConsumptionVarnish_3d_job                       23533 non-null  float64
#  8   run                                                    23533 non-null  int64
#  9   total_run                                              23533 non-null  int64
#  10  copies_per_run                                         23533 non-null  int64
#  11  jobId                                                  23533 non-null  int64
#  12  total_copies_requested                                 23533 non-null  int64
#  13  LED                                                    23533 non-null  int64
#  14  bars_event                                             23533 non-null  object
#  15  drops                                                  23533 non-null  int64
#  16  dithering                                              23533 non-null  bool
#  17  deadPixelsOffset                                       23533 non-null  int64
#  18  operator_level                                         23533 non-null  object
#  19  operator                                               23533 non-null  object
#  20  speed_ifoil                                            23533 non-null  float64
#  21  ifoil                                                  23533 non-null  bool
#  22  optifoil_ifoil                                         23533 non-null  bool
#  23  stampAreas_ifoil                                       23533 non-null  object
#  24  heater1Enabled_ifoil                                   23533 non-null  bool
#  25  speedTensionIn_ifoil                                   23533 non-null  float64
#  26  speedTensionOut_ifoil                                  23533 non-null  float64
#  27  heater1Temperature_ifoil                               23533 non-null  int64
#  28  x_imageLayout                                          23533 non-null  int64
#  29  y_imageLayout                                          23533 non-null  int64
#  30  paperName                                              23533 non-null  object
#  31  paperWidth_event                                       23533 non-null  float64
#  32  paperHeight_event                                      23533 non-null  float64
#  33  speed                                                  23533 non-null  int64
#  34  power_irDryers                                         23533 non-null  int64
#  35  power_uvDryers                                         23533 non-null  int64
#  36  redScore_gridMode_remoteScannerRegistration            23533 non-null  int64
#  37  redScore_cropmarksMode_remoteScannerRegistration       23533 non-null  int64
#  38  x_cropmark1_cropmarksMode_remoteScannerRegistration    23533 non-null  int64
#  39  y_cropmark1_cropmarksMode_remoteScannerRegistration    23533 non-null  int64
#  40  x_cropmark2_cropmarksMode_remoteScannerRegistration    23533 non-null  int64
#  41  y_cropmark2_cropmarksMode_remoteScannerRegistration    23533 non-null  int64
#  42  exposureTime_manualLighting_remoteScannerRegistration  23533 non-null  int64
#  43  redScore_fullScannerMode_remoteScannerRegistration     23533 non-null  int64
#  44  blueScore_fullScannerMode_remoteScannerRegistration    23533 non-null  int64
#  45  greenScore_fullScannerMode_remoteScannerRegistration   23533 non-null  int64
#  46  enable_specialSubstrate_remoteScannerRegistration      23533 non-null  bool
#  47  mode_remoteScannerRegistration                         23533 non-null  int64
#  48  jobState                                               23533 non-null  object
#  49  total_copies_event                                     23533 non-null  int64
#  50  varnishConsumptionVarnish_3d_event                     23533 non-null  float64
#  51  index                                                  23533 non-null  int64
#  52  timestamp                                              23533 non-null  object
#  53  criticality_events                                     23533 non-null  object
#  54  identification_events                                  23533 non-null  int64
# dtypes: bool(5), float64(7), int64(33), object(10)
# memory usage: 9.3+ MB

# %% [markdown]
# ## B) Analyse des variables

# %%
# remise à zero des index
df.reset_index(drop=True,inplace=True)

# %%
# suppression des colonnes de metrics
# metrics_cols = [
#     'status', 
#     'source_events', 
#     'timestamp', 
#     'criticality_events', 
#     'name_modules', 
#     'type_modules',
#     'generation_modules', 
#     'value_counters_modules', 
#     'name_counters_modules',
#     'name_connected_operators',
#     'level_connected_operators',
#     'varnishLevelsTargetvolume',
#     'varnishLevelsTotalvolume'
#     ]
metrics_cols = [
    'timestamp', 
    'identification_events', 
    'index',
    ]
df.drop(columns=metrics_cols, axis=0, inplace=True)

# %%
# suppression des colonnes en doublon entre job_events et jobs
job_events_cols = [
    'bars_event',
    'paperWidth_event', 
    'paperHeight_event',
    'varnishConsumptionVarnish_3d_event'
    ]
df.drop(columns=job_events_cols, axis=0, inplace=True)

# %%
# suppression des colonnes de variables catégorielles
cat_cols = [
    'operator_level', 
    'operator',
    'paperName', 
    'jobState',
    'jobId'
   ]
df.drop(columns=cat_cols, axis=0, inplace=True)

# %%
# suppression des colonnes datetime et ajout d'une colonne duration
df['started_at'] = pd.to_datetime(df['started_at'])
df['ended_at'] = pd.to_datetime(df['ended_at'])
# Calculer la différence de temps entre les deux colonnes
df['duration'] = (df['ended_at'] - df['started_at']).dt.total_seconds()
df.drop(columns=['started_at', 'ended_at'], axis=0, inplace=True)

# %%
df.head(3)
# Out:
#    total_copies_job  paperHeight_job  paperWidth_job  scanner_mode  bars_job  \
# 0                47              483             330             3         2
# 1                47              483             330             3         2
# 2                47              483             330             3         2
#
#    varnishConsumptionVarnish_3d_job  run  total_run  copies_per_run  \
# 0                          4.814659    0          0               0
# 1                          4.814659    0          0               0
# 2                          4.814659    0          0               0
#
#    total_copies_requested  LED  drops  dithering  deadPixelsOffset  \
# 0                      47   50      3      False                 1
# 1                      47   50      3      False                 1
# 2                      47   50      3      False                 1
#
#    speed_ifoil  ifoil  optifoil_ifoil  \
# 0         23.0   True           False
# 1         23.0   True           False
# 2         23.0   True           False
#
#                                     stampAreas_ifoil  heater1Enabled_ifoil  \
# 0  [{'id': 1, 'end': 490, 'start': 0, 'height': 4...                  True
# 1  [{'id': 1, 'end': 490, 'start': 0, 'height': 4...                  True
# 2  [{'id': 1, 'end': 490, 'start': 0, 'height': 4...                  True
#
#    speedTensionIn_ifoil  speedTensionOut_ifoil  heater1Temperature_ifoil  \
# 0                  -1.0                    1.0                        90
# 1                  -1.0                    1.0                        90
# 2                  -1.0                    1.0                        90
#
#    x_imageLayout  y_imageLayout  speed  power_irDryers  power_uvDryers  \
# 0           1500            -27    418              45              65
# 1           1500            -27    418              45              65
# 2           1500            -27    418              45              65
#
#    redScore_gridMode_remoteScannerRegistration  \
# 0                                         1500
# 1                                         1500
# 2                                         1500
#
#    redScore_cropmarksMode_remoteScannerRegistration  \
# 0                                              1500
# 1                                              1500
# 2                                              1500
#
#    x_cropmark1_cropmarksMode_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    y_cropmark1_cropmarksMode_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    x_cropmark2_cropmarksMode_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    y_cropmark2_cropmarksMode_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    exposureTime_manualLighting_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    redScore_fullScannerMode_remoteScannerRegistration  \
# 0                                               1500
# 1                                               1500
# 2                                               1500
#
#    blueScore_fullScannerMode_remoteScannerRegistration  \
# 0                                                 20
# 1                                                 20
# 2                                                 20
#
#    greenScore_fullScannerMode_remoteScannerRegistration  \
# 0                                                 20
# 1                                                 20
# 2                                                 20
#
#    enable_specialSubstrate_remoteScannerRegistration  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#    mode_remoteScannerRegistration  total_copies_event criticality_events  \
# 0                               3                  47               INFO
# 1                               3                  47               INFO
# 2                               3                  47           NO_EVENT
#
#    duration
# 0   352.944
# 1   352.944
# 2   352.944

# %%
# Liste des colonnes à vérifier
colonnes_a_verifier = ['dithering','deadPixelsOffset','speedTensionIn_ifoil']

# Vérifier le nombre de valeurs uniques pour chaque colonne dans la liste
nombres_uniques = df[colonnes_a_verifier].nunique()

print(nombres_uniques)
# Out:
# dithering                2
# deadPixelsOffset         3
# speedTensionIn_ifoil    12
# dtype: int64

# %% [markdown]
# ## C) Nettoyage

# %%
# supression des colonnes dont les valeurs sont constantes
# contstant_cols = ['dithering','speedTensionIn_ifoil']

constant_cols = [col for col in df.columns if df[col].nunique() == 1]
print(constant_cols)
df.drop(columns=constant_cols, axis=0, inplace=True)
# Out:
# ['optifoil_ifoil']

# %%
df.head(5)
# Out:
#    total_copies_job  paperHeight_job  paperWidth_job  scanner_mode  bars_job  \
# 0                47              483             330             3         2
# 1                47              483             330             3         2
# 2                47              483             330             3         2
# 3                47              483             330             3         2
# 4                47              483             330             3         2
#
#    varnishConsumptionVarnish_3d_job  run  total_run  copies_per_run  \
# 0                          4.814659    0          0               0
# 1                          4.814659    0          0               0
# 2                          4.814659    0          0               0
# 3                          4.814659    0          0               0
# 4                          4.814659    0          0               0
#
#    total_copies_requested  LED  drops  dithering  deadPixelsOffset  \
# 0                      47   50      3      False                 1
# 1                      47   50      3      False                 1
# 2                      47   50      3      False                 1
# 3                      47   50      3      False                 1
# 4                      47   50      3      False                 1
#
#    speed_ifoil  ifoil                                   stampAreas_ifoil  \
# 0         23.0   True  [{'id': 1, 'end': 490, 'start': 0, 'height': 4...
# 1         23.0   True  [{'id': 1, 'end': 490, 'start': 0, 'height': 4...
# 2         23.0   True  [{'id': 1, 'end': 490, 'start': 0, 'height': 4...
# 3         23.0   True  [{'id': 1, 'end': 490, 'start': 0, 'height': 4...
# 4         23.0   True  [{'id': 1, 'end': 490, 'start': 0, 'height': 4...
#
#    heater1Enabled_ifoil  speedTensionIn_ifoil  speedTensionOut_ifoil  \
# 0                  True                  -1.0                    1.0
# 1                  True                  -1.0                    1.0
# 2                  True                  -1.0                    1.0
# 3                  True                  -1.0                    1.0
# 4                  True                  -1.0                    1.0
#
#    heater1Temperature_ifoil  x_imageLayout  y_imageLayout  speed  \
# 0                        90           1500            -27    418
# 1                        90           1500            -27    418
# 2                        90           1500            -27    418
# 3                        90           1500            -27    418
# 4                        90           1500            -27    418
#
#    power_irDryers  power_uvDryers  \
# 0              45              65
# 1              45              65
# 2              45              65
# 3              45              65
# 4              45              65
#
#    redScore_gridMode_remoteScannerRegistration  \
# 0                                         1500
# 1                                         1500
# 2                                         1500
# 3                                         1500
# 4                                         1500
#
#    redScore_cropmarksMode_remoteScannerRegistration  \
# 0                                              1500
# 1                                              1500
# 2                                              1500
# 3                                              1500
# 4                                              1500
#
#    x_cropmark1_cropmarksMode_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    y_cropmark1_cropmarksMode_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    x_cropmark2_cropmarksMode_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    y_cropmark2_cropmarksMode_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    exposureTime_manualLighting_remoteScannerRegistration  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    redScore_fullScannerMode_remoteScannerRegistration  \
# 0                                               1500
# 1                                               1500
# 2                                               1500
# 3                                               1500
# 4                                               1500
#
#    blueScore_fullScannerMode_remoteScannerRegistration  \
# 0                                                 20
# 1                                                 20
# 2                                                 20
# 3                                                 20
# 4                                                 20
#
#    greenScore_fullScannerMode_remoteScannerRegistration  \
# 0                                                 20
# 1                                                 20
# 2                                                 20
# 3                                                 20
# 4                                                 20
#
#    enable_specialSubstrate_remoteScannerRegistration  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    mode_remoteScannerRegistration  total_copies_event criticality_events  \
# 0                               3                  47               INFO
# 1                               3                  47               INFO
# 2                               3                  47           NO_EVENT
# 3                               3                  47               INFO
# 4                               3                  47               INFO
#
#    duration
# 0   352.944
# 1   352.944
# 2   352.944
# 3   352.944
# 4   352.944

# %%
# Vérifier si toutes les valeurs dans les deux colonnes sont identiques
same_col = (df['total_copies_job'] == df['total_copies_event']).all()
print("Les colonnes sont-elles identiques ?", same_col)
# Out:
# Les colonnes sont-elles identiques ? True

# %%
df.shape
# Out:
# (23533, 41)

# %%
# Supprimer la colonne 'total_copies_event'
df.drop(columns='total_copies_event', inplace=True)

# Renommer la colonne 'total_copies_job' en 'total_copies'
df.rename(columns={'total_copies_job': 'total_copies'}, inplace=True)

# %%
df.shape
# Out:
# (23533, 40)

# %% [markdown]
# <style>
#     .important {color: #A5EF6E;}
#     .purple { color: #EF6EE9;}
# </style>
#
# Données disponibles au démarrage d'un job :
# - <span class='important'>1  thumbnail* : chemin vignette projet</span>
# - 2  total_copies : nombre de copies imprimées
# - 3  started_at : date de début
# - 4  ended_at : date de fin
# - <span class='important'>5  machineId* : identifiant machine</span>
# - 6  speed : vitesse d'impression
# - 7  operator : opérateur
# - 8  operator_level : niveau de l'opérateur
# - 9  first_page_image_path_on_machine* : chemin de l'image
# - 10 paperHeight : hauteur du substrat
# - 11 paperWidth : largeur du substrat
# - 12 paperName : appelation du substrat
# - <span class='important'>13 paperThickness* : épaisseur du substrat (valeur unique à 0)</span>
# - 14 id_on_machine : identifiant unique du travail d'impression
# - 15 total_copies_requested : nombre de copies demandées
# - <span class='important'>16 job_thumbnail_id* : identifiant de vignette image</span>
# - 17 uses_ifoil : impression utilisant de la dorure
# - <span class='important'>18 uses_iper* : impression nécéssitant l'iper (valeur unique à True)</span>
# - 19 scanner_mode : niveau de config du scanner
# - 20 iper_bvar_count : compteur <span class='purple'># TODO vérifier la fusion notebook 06</span>
# - 21 varnishConsumptionVarnish_3d : consommation de vernis en 3d
# - <span class='important'>22 varnishConsumptionVarnish_2d* : consommation de vernis en 2d</span>
#
# <span class='important'> *\*variables déjà supprimées dans le notebook 05 ou 06*</span>

# %%
# colonnes à conserver dispos dans jobs
jobs_cols_to_keep = [
    'duration',
    'total_copies',
    'speed',
    'paperHeight_job', 
    'paperWidth_job', 
    'total_copies_requested',
    'ifoil',
    'scanner_mode', 
    'bars_job',
    'varnishConsumptionVarnish_3d_job'
    ]
# colonnes à conserver dispos dans job events avec le tag start
jobevents_cols_to_keep = [
    'LED',
    'drops', 
    'speed_ifoil',
    'stampAreas_ifoil',
    'heater1Enabled_ifoil', 
    'heater1Temperature_ifoil',
    'x_imageLayout',
    'y_imageLayout', 
    'power_irDryers', 
    'power_uvDryers',
    'redScore_gridMode_remoteScannerRegistration',
    'redScore_cropmarksMode_remoteScannerRegistration',
    'redScore_fullScannerMode_remoteScannerRegistration',
    'blueScore_fullScannerMode_remoteScannerRegistration',
    'greenScore_fullScannerMode_remoteScannerRegistration',
    'mode_remoteScannerRegistration'
    ]
# colonnes à conserver pour la prédiction
metrics_cols_to_keep = ['criticality_events']

# fusion des listes de colonnes à conserver
cols_to_keep = jobs_cols_to_keep + jobevents_cols_to_keep + metrics_cols_to_keep

# dataframe des variables conservées
df_to_encode = df[cols_to_keep].copy()

# %%
df_to_encode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23533 entries, 0 to 23532
# Data columns (total 27 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   duration                                              23533 non-null  float64
#  1   total_copies                                          23533 non-null  int64
#  2   speed                                                 23533 non-null  int64
#  3   paperHeight_job                                       23533 non-null  int64
#  4   paperWidth_job                                        23533 non-null  int64
#  5   total_copies_requested                                23533 non-null  int64
#  6   ifoil                                                 23533 non-null  bool
#  7   scanner_mode                                          23533 non-null  int64
#  8   bars_job                                              23533 non-null  int64
#  9   varnishConsumptionVarnish_3d_job                      23533 non-null  float64
#  10  LED                                                   23533 non-null  int64
#  11  drops                                                 23533 non-null  int64
#  12  speed_ifoil                                           23533 non-null  float64
#  13  stampAreas_ifoil                                      23533 non-null  object
#  14  heater1Enabled_ifoil                                  23533 non-null  bool
#  15  heater1Temperature_ifoil                              23533 non-null  int64
#  16  x_imageLayout                                         23533 non-null  int64
#  17  y_imageLayout                                         23533 non-null  int64
#  18  power_irDryers                                        23533 non-null  int64
#  19  power_uvDryers                                        23533 non-null  int64
#  20  redScore_gridMode_remoteScannerRegistration           23533 non-null  int64
#  21  redScore_cropmarksMode_remoteScannerRegistration      23533 non-null  int64
#  22  redScore_fullScannerMode_remoteScannerRegistration    23533 non-null  int64
#  23  blueScore_fullScannerMode_remoteScannerRegistration   23533 non-null  int64
#  24  greenScore_fullScannerMode_remoteScannerRegistration  23533 non-null  int64
#  25  mode_remoteScannerRegistration                        23533 non-null  int64
#  26  criticality_events                                    23533 non-null  object
# dtypes: bool(2), float64(3), int64(20), object(2)
# memory usage: 4.5+ MB

# %%
df_to_encode.drop(columns=['stampAreas_ifoil', 'total_copies', 'mode_remoteScannerRegistration'], axis=0, inplace=True)

# %%
df_to_encode.criticality_events.unique()
# Out:
# array(['INFO', 'NO_EVENT', 'ERROR', 'WARNING'], dtype=object)

# %% [markdown]
# ## D) Output

# %%
df_to_encode.to_csv(save_csv)
